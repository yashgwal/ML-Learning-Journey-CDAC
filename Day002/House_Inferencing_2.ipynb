# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer,make_column_selector
import os
os.chdir('/home/pgcp-ai/MachineLearning/Datasets')

# %%
housing = pd.read_csv('Housing.csv')
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
X,y = housing.drop('price',axis=1),housing['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=26)

# %%
ohe = OneHotEncoder(sparse_output = False, drop='first').set_output(transform='pandas')

# %%
transformer_1 = ColumnTransformer(transformers=[("OHE",ohe,make_column_selector(dtype_include=object))
                                               ],
                                 remainder='passthrough',
                                 verbose_feature_names_out=False).set_output(transform='pandas')
transformer_1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('OHE',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fcac6cec790>)],
#                   verbose_feature_names_out=False)

# %%
X_train_transform = transformer_1.fit_transform(X_train)
X_test_transform = transformer_1.transform(X_test)

# %%
X_train_transform.columns
# Out:
# Index(['driveway_yes', 'recroom_yes', 'fullbase_yes', 'gashw_yes', 'airco_yes',
#        'prefarea_yes', 'lotsize', 'bedrooms', 'bathrms', 'stories',
#        'garagepl'],
#       dtype='object')

# %%
X_test_transform.columns
# Out:
# Index(['driveway_yes', 'recroom_yes', 'fullbase_yes', 'gashw_yes', 'airco_yes',
#        'prefarea_yes', 'lotsize', 'bedrooms', 'bathrms', 'stories',
#        'garagepl'],
#       dtype='object')

# %%
model = LinearRegression()
model.fit(X_train_transform,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_transform)

# %%
print(f"R2 Score = {r2_score(y_test,y_pred)}")
# Out:
# R2 Score = 0.6791781818067948

# %%
tst = pd.read_csv("tst_Housing.csv")

# %%
bm = LinearRegression()
X_ohe = transformer_1.fit_transform(X)
bm.fit(X_ohe, y)
X_ohe.columns
# Out:
# Index(['driveway_yes', 'recroom_yes', 'fullbase_yes', 'gashw_yes', 'airco_yes',
#        'prefarea_yes', 'lotsize', 'bedrooms', 'bathrms', 'stories',
#        'garagepl'],
#       dtype='object')

# %%
tst_ohe = transformer_1.transform(tst)
tst_ohe.columns
# Out:
# Index(['driveway_yes', 'recroom_yes', 'fullbase_yes', 'gashw_yes', 'airco_yes',
#        'prefarea_yes', 'lotsize', 'bedrooms', 'bathrms', 'stories',
#        'garagepl'],
#       dtype='object')

# %%
bm.predict(tst_ohe)
# Out:
# array([65151.39992985, 42650.08901117, 41137.92877603, 76249.38318098])
