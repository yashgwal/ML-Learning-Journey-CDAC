# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, accuracy_score, f1_score, confusion_matrix, precision_score, recall_score, classification_report,roc_auc_score,roc_curve,RocCurveDisplay
import os
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from tqdm import tqdm
os.chdir('/home/pgcp-ai/MachineLearning/Cases/Image_Segmentation/')

# %%
img = pd.read_csv("Image_Segmentation.csv")
img
# Out:
#          Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0    BRICKFACE                  188                  133                   9
# 1    BRICKFACE                  105                  139                   9
# 2    BRICKFACE                   34                  137                   9
# 3    BRICKFACE                   39                  111                   9
# 4    BRICKFACE                   16                  128                   9
# ..         ...                  ...                  ...                 ...
# 204      GRASS                   36                  243                   9
# 205      GRASS                  186                  218                   9
# 206      GRASS                  197                  236                   9
# 207      GRASS                  208                  240                   9
# 208      GRASS                  223                  185                   9
#
#      short.line.density.5  short.line.density.2  vedge.mean  vegde.sd  \
# 0                0.000000                   0.0    0.333333  0.266667
# 1                0.000000                   0.0    0.277778  0.107407
# 2                0.000000                   0.0    0.500000  0.166667
# 3                0.000000                   0.0    0.722222  0.374074
# 4                0.000000                   0.0    0.500000  0.077778
# ..                    ...                   ...         ...       ...
# 204              0.111111                   0.0    1.888889  1.851851
# 205              0.000000                   0.0    1.166667  0.744444
# 206              0.000000                   0.0    2.444444  6.829628
# 207              0.111111                   0.0    1.055556  0.862963
# 208              0.000000                   0.0    0.500000  0.349603
#
#      hedge.mean  hedge.sd  intensity.mean  rawred.mean  rawblue.mean  \
# 0      0.500000  0.077778        6.666666     8.333334      7.777778
# 1      0.833333  0.522222        6.111111     7.555555      7.222222
# 2      1.111111  0.474074        5.851852     7.777778      6.444445
# 3      0.888889  0.429629        6.037037     7.000000      7.666666
# 4      0.666667  0.311111        5.555555     6.888889      6.666666
# ..          ...       ...             ...          ...           ...
# 204    2.000000  0.711110       13.333333     9.888889     12.111111
# 205    1.166667  0.655555       13.703704    10.666667     12.666667
# 206    3.333333  7.599998       16.074074    13.111111     16.666668
# 207    2.444444  5.007407       14.148149    10.888889     13.000000
# 208    2.388889  2.080776       12.962963    11.555555      9.777778
#
#      rawgreen.mean  exred.mean  exblue.mean  exgreen.mean  value.mean  \
# 0         3.888889    5.000000     3.333333     -8.333333    8.444445
# 1         3.555556    4.333334     3.333333     -7.666666    7.555555
# 2         3.333333    5.777778     1.777778     -7.555555    7.777778
# 3         3.444444    2.888889     4.888889     -7.777778    7.888889
# 4         3.111111    4.000000     3.333333     -7.333334    7.111111
# ..             ...         ...          ...           ...         ...
# 204      18.000000  -10.333333    -3.666667     14.000000   18.000000
# 205      17.777779   -9.111111    -3.111111     12.222222   17.777779
# 206      18.444445   -8.888889     1.777778      7.111111   18.555555
# 207      18.555555   -9.777778    -3.444444     13.222222   18.555555
# 208      17.555555   -4.222222    -9.555555     13.777778   17.555555
#
#      saturation.mean  hue-mean
# 0           0.538580 -0.924817
# 1           0.532628 -0.965946
# 2           0.573633 -0.744272
# 3           0.562919 -1.175773
# 4           0.561508 -0.985811
# ..               ...       ...
# 204         0.452229  2.368311
# 205         0.401347  2.382684
# 206         0.292729  2.789800
# 207         0.421621  2.392487
# 208         0.445418  1.838850
#
# [209 rows x 20 columns]

# %%
img.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 209 non-null    object
#  1   region.centroid.col   209 non-null    int64
#  2   region.centroid.row   209 non-null    int64
#  3   region.pixel.count    209 non-null    int64
#  4   short.line.density.5  209 non-null    float64
#  5   short.line.density.2  209 non-null    float64
#  6   vedge.mean            209 non-null    float64
#  7   vegde.sd              209 non-null    float64
#  8   hedge.mean            209 non-null    float64
#  9   hedge.sd              209 non-null    float64
#  10  intensity.mean        209 non-null    float64
#  11  rawred.mean           209 non-null    float64
#  12  rawblue.mean          209 non-null    float64
#  13  rawgreen.mean         209 non-null    float64
#  14  exred.mean            209 non-null    float64
#  15  exblue.mean           209 non-null    float64
#  16  exgreen.mean          209 non-null    float64
#  17  value.mean            209 non-null    float64
#  18  saturation.mean       209 non-null    float64
#  19  hue-mean              209 non-null    float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 32.8+ KB

# %%
img.isna().sum()
# Out:
# Class                   0
# region.centroid.col     0
# region.centroid.row     0
# region.pixel.count      0
# short.line.density.5    0
# short.line.density.2    0
# vedge.mean              0
# vegde.sd                0
# hedge.mean              0
# hedge.sd                0
# intensity.mean          0
# rawred.mean             0
# rawblue.mean            0
# rawgreen.mean           0
# exred.mean              0
# exblue.mean             0
# exgreen.mean            0
# value.mean              0
# saturation.mean         0
# hue-mean                0
# dtype: int64

# %%
le = LabelEncoder()
img["Class"] = le.fit_transform(img["Class"])

# %%
X, y = img.drop("Class", axis = 1), img["Class"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,stratify=y,random_state=26)

# %%
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
Cs = np.linspace(0.001,5,20)
dfs = ['ovo', 'ovr']
scores = []
for c in tqdm(Cs):
    for f in dfs:
        svm = SVC(kernel='linear',C=c,probability=True,random_state=26, decision_function_shape=f)
        svm.fit(X_train,y_train)
        y_pred = svm.predict(X_test)
        acc = accuracy_score(y_test,y_pred)
        y_pred_prob = svm.predict_proba(X_test)
        log_loss_score = log_loss(y_test,y_pred_prob)
        scores.append([c,f, acc,log_loss_score])
# Out:
# 100%|███████████████████████████████████████████| 20/20 [00:00<00:00, 46.42it/s]

# %%
df_scores = pd.DataFrame(scores,columns=['C','Decision Function', 'Accuracy Score','Log Loss'])
df_scores.sort_values('Log Loss',ascending=True)
# Out:
#            C Decision Function  Accuracy Score  Log Loss
# 2   0.264105               ovo        0.936508  0.629300
# 3   0.264105               ovr        0.936508  0.629300
# 4   0.527211               ovo        0.920635  0.661606
# 5   0.527211               ovr        0.920635  0.661606
# 6   0.790316               ovo        0.920635  0.679109
# 7   0.790316               ovr        0.920635  0.679109
# 8   1.053421               ovo        0.904762  0.688156
# 9   1.053421               ovr        0.904762  0.688156
# 10  1.316526               ovo        0.904762  0.693341
# 11  1.316526               ovr        0.904762  0.693341
# 12  1.579632               ovo        0.904762  0.694479
# 13  1.579632               ovr        0.904762  0.694479
# 14  1.842737               ovo        0.904762  0.698139
# 15  1.842737               ovr        0.904762  0.698139
# 17  2.105842               ovr        0.904762  0.701473
# 16  2.105842               ovo        0.904762  0.701473
# 18  2.368947               ovo        0.904762  0.704079
# 19  2.368947               ovr        0.904762  0.704079
# 22  2.895158               ovo        0.920635  0.704145
# 23  2.895158               ovr        0.920635  0.704145
# 20  2.632053               ovo        0.920635  0.704817
# 21  2.632053               ovr        0.920635  0.704817
# 24  3.158263               ovo        0.920635  0.705640
# 25  3.158263               ovr        0.920635  0.705640
# 26  3.421368               ovo        0.920635  0.710367
# 27  3.421368               ovr        0.920635  0.710367
# 28  3.684474               ovo        0.920635  0.714712
# 29  3.684474               ovr        0.920635  0.714712
# 30  3.947579               ovo        0.920635  0.716374
# 31  3.947579               ovr        0.920635  0.716374
# 33  4.210684               ovr        0.920635  0.717884
# 32  4.210684               ovo        0.920635  0.717884
# 35  4.473789               ovr        0.920635  0.719439
# 34  4.473789               ovo        0.920635  0.719439
# 36  4.736895               ovo        0.904762  0.720881
# 37  4.736895               ovr        0.904762  0.720881
# 39  5.000000               ovr        0.904762  0.722728
# 38  5.000000               ovo        0.904762  0.722728
# 1   0.001000               ovr        0.682540  1.816507
# 0   0.001000               ovo        0.682540  1.816507

# %%
Cs = np.linspace(0.001,5,20)
Gs = np.linspace(0.001, 5, 20)
dfs = ['ovo', 'ovr']
scores = []
for c in tqdm(Cs):
    for f in dfs: 
        for g in Gs:
            svm = SVC(kernel='rbf',C=c,probability=True,gamma = g,random_state=26,decision_function_shape=f)
            svm.fit(X_train,y_train)
            y_pred = svm.predict(X_test)
            acc = accuracy_score(y_test,y_pred)
            y_pred_prob = svm.predict_proba(X_test)
            log_loss_score = log_loss(y_test,y_pred_prob)
            scores.append([c,f,g,acc,log_loss_score])
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]

# %%
df_scores = pd.DataFrame(scores, columns = ['C','Decision Function','G', 'Accuracy Score', 'Log Loss'])

# %%
df_scores.sort_values(['Log Loss', 'Accuracy Score'], ascending = [True, False])
# Out:
#             C Decision Function         G  Accuracy Score  Log Loss
# 242  1.579632               ovo  0.264105        0.920635  0.491097
# 243  1.579632               ovr  0.264105        0.920635  0.491097
# 282  1.842737               ovo  0.264105        0.920635  0.492866
# 283  1.842737               ovr  0.264105        0.920635  0.492866
# 202  1.316526               ovo  0.264105        0.920635  0.493293
# ..        ...               ...       ...             ...       ...
# 71   0.264105               ovr  3.947579        0.349206  1.999678
# 66   0.264105               ovo  3.421368        0.365079  1.999724
# 67   0.264105               ovr  3.421368        0.365079  1.999724
# 68   0.264105               ovo  3.684474        0.349206  2.000049
# 69   0.264105               ovr  3.684474        0.349206  2.000049
#
# [800 rows x 5 columns]
