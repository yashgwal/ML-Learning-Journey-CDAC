# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, accuracy_score, f1_score, confusion_matrix, precision_score, recall_score, classification_report,roc_auc_score,roc_curve,RocCurveDisplay
import os
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
os.chdir('/home/pgcp-ai/MachineLearning/Cases/Image_Segmentation/')

# %%
image = pd.read_csv("Image_Segmentation.csv")
image
# Out:
#          Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0    BRICKFACE                  188                  133                   9
# 1    BRICKFACE                  105                  139                   9
# 2    BRICKFACE                   34                  137                   9
# 3    BRICKFACE                   39                  111                   9
# 4    BRICKFACE                   16                  128                   9
# ..         ...                  ...                  ...                 ...
# 204      GRASS                   36                  243                   9
# 205      GRASS                  186                  218                   9
# 206      GRASS                  197                  236                   9
# 207      GRASS                  208                  240                   9
# 208      GRASS                  223                  185                   9
#
# ...

# %% [markdown]
# ### LDA as a Data Transformer

# %%
lda = LinearDiscriminantAnalysis().set_output(transform = 'pandas')
X, y = image.drop('Class', axis = 1), image['Class']
lda = LinearDiscriminantAnalysis().set_output(transform='pandas')
X_lda = lda.fit_transform(X, y)
lda_data = pd.concat([X_lda, y], axis = 1)
lda_data
# Out:
#      lineardiscriminantanalysis0  lineardiscriminantanalysis1  \
# 0                       0.589119                     4.278844
# 1                       0.450417                     4.154446
# 2                       2.091867                     4.449199
# 3                       0.150416                     4.506612
# 4                       0.823607                     4.340618
# ..                           ...                          ...
# 204                    14.752466                    -1.865171
# 205                    13.371916                    -1.384433
# 206                    12.179366                    -1.335292
# 207                    14.056916                    -1.956963
# 208                    13.565506                    -0.145205
#
#      lineardiscriminantanalysis2  lineardiscriminantanalysis3  \
# 0                       0.857238                     1.634340
# 1                       0.459624                     1.236909
# ...

# %%
X_lda.shape,X.shape
# Out:
# ((209, 6), (209, 19))

# %%
X_train,X_test,y_train,y_test = train_test_split(X_lda,y,test_size=0.3,stratify=y)

# %% [markdown]
# ### LDA as a Classifier

# %%
lda_classifier = LinearDiscriminantAnalysis()
lda_classifier.fit(X_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pred = lda_classifier.predict(X_test)
y_pred_prob = lda_classifier.predict_proba(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9206349206349206

# %%
log_loss(y_test,y_pred_prob)
# Out:
# 0.26148143300546406

# %%
sns.scatterplot(data = lda_data, x = 'lineardiscriminantanalysis0',
                y = 'lineardiscriminantanalysis1', hue = 'Class',palette='Dark2')
plt.show()

# %%
sns.scatterplot(data = lda_data, x = 'lineardiscriminantanalysis1',
                y = 'lineardiscriminantanalysis2', hue = 'Class',palette='Dark2')
plt.show()

# %%
sns.pairplot(data=lda_data,hue='Class',palette='Dark2')

# %%
sns.heatmap(X_lda.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lda_data_mock = lda_data.copy()
le = LabelEncoder()
lda_data_mock['Class'] = le.fit_transform(lda_data_mock['Class'])

# %%
sns.heatmap(lda_data_mock.corr(),annot=True)
# Out:
# <Axes: >
