# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.compose import ColumnTransformer, make_column_selector
import os
os.chdir('/home/pgcp-ai/MachineLearning/Cases/Wisconsin/')

# %% [markdown]
# #### We stratify for the better representation of train and test data with respect to the original data.
# #### Stratification keeps the proportions of `y` variable similar in case of both train and test data
# #### stratify parameter should always be a categorical variable

# %%
cancer = pd.read_csv("BreastCancer.csv")
X, y = cancer.drop(["Code", "Class"], axis = 1), cancer["Class"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 26, stratify = cancer["Class"])

# %%
y.value_counts()
# Out:
# Class
# Benign       458
# Malignant    241
# Name: count, dtype: int64

# %%
y.value_counts(normalize = True) * 100
# Out:
# Class
# Benign       65.522175
# Malignant    34.477825
# Name: proportion, dtype: float64

# %%
y_train.value_counts(normalize=True)*100
# Out:
# Class
# Benign       65.439673
# Malignant    34.560327
# Name: proportion, dtype: float64

# %%
y_test.value_counts(normalize = True) * 100
# Out:
# Class
# Benign       65.714286
# Malignant    34.285714
# Name: proportion, dtype: float64

# %%
y_train.value_counts()
# Out:
# Class
# Benign       320
# Malignant    169
# Name: count, dtype: int64
