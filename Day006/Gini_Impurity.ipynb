# %%
f1,f2 = (50 / 100), (50/100)
f1*(1-f1) + f2*(1-f2)
# Out:
# 0.5

# %%
f1,f2 = (40 / 100), (60/100)
f1*(1-f1) + f2*(1-f2)
# Out:
# 0.48

# %%
f1,f2 = (80 / 100), (20/100)
f1*(1-f1) + f2*(1-f2)
# Out:
# 0.32

# %%
f1,f2 = (10 / 100), (90/100)
f1*(1-f1) + f2*(1-f2)
# Out:
# 0.18

# %%
depths = [2,3]
