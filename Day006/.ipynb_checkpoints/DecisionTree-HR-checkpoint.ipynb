# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier,plot_tree 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,log_loss
from tqdm import tqdm
import os
os.chdir("/home/pgcp-ai/MachineLearning/Cases/Wisconsin/")

# %%
cancer = pd.read_csv("BreastCancer.csv",index_col='Code')
cancer
# Out:
#           Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# Code
# 61634         5             4              3        1       2      2
# 63375         9             1              2        6       4     10
# 76389        10             4              7        2       2      8
# 95719         6            10             10       10       8     10
# 128059        1             1              1        1       2      5
# ...         ...           ...            ...      ...     ...    ...
# 1369821      10            10             10       10       5     10
# 1371026       5            10             10       10       4     10
# 1371920       5             1              1        1       2      1
# 8233704       4             1              1        1       1      1
# 13454352      1             1              3        1       2      1
#
#           BChromatin  NoemN  Mitoses      Class
# Code
# 61634              2      3        1     Benign
# ...

# %%
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 699 entries, 61634 to 13454352
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Clump          699 non-null    int64
#  1   UniCell_Size   699 non-null    int64
#  2   Uni_CellShape  699 non-null    int64
#  3   MargAdh        699 non-null    int64
#  4   SEpith         699 non-null    int64
#  5   BareN          699 non-null    int64
#  6   BChromatin     699 non-null    int64
#  7   NoemN          699 non-null    int64
#  8   Mitoses        699 non-null    int64
#  9   Class          699 non-null    object
# dtypes: int64(9), object(1)
# memory usage: 60.1+ KB

# %%
cancer.isna().sum()
# Out:
# Clump            0
# UniCell_Size     0
# Uni_CellShape    0
# MargAdh          0
# SEpith           0
# BareN            0
# BChromatin       0
# NoemN            0
# Mitoses          0
# Class            0
# dtype: int64

# %%
X,y = cancer.drop("Class", axis = 1), cancer["Class"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state = 26, stratify = y)

# %%
dtc = DecisionTreeClassifier(criterion='gini')
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize = (25,10))
plot_tree(dtc,filled=True, rounded = True,feature_names=list(X.columns),class_names=['Benign','Malignant'],fontsize=12)
plt.show()

# %%
y_pred = dtc.predict(X_test)
y_pred_prob = dtc.predict_proba(X_test)

# %%
print(f"Accuracy Score: {accuracy_score(y_test,y_pred)}")
print(f"Log Loss: {log_loss(y_test,y_pred_prob)}")
# Out:
# Accuracy Score: 0.9476190476190476
# Log Loss: 1.8880008918108986

# %%
depths = [1,2,3,4,5,6]
splits = []
scores = []
for d in tqdm(depths):
    dtc = DecisionTreeClassifier(criterion='gini',max_depth=d,random_state=26)
    dtc.fit(X_train, y_train)
    y_pred_prob = dtc.predict_proba(X_test)
    y_pred = dtc.predict(X_test)
    scores.append([d,log_loss(y_test,y_pred_prob),accuracy_score(y_test,y_pred)])
    
df_scores = pd.DataFrame(scores,columns=["Depth","Log Loss","Accuracy"])
df_scores.sort_values('Log Loss')
# Out:
# 100%|████████████████████████████████████████████| 6/6 [00:00<00:00, 101.74it/s]
#    Depth  Log Loss  Accuracy
# 1      2  0.213198  0.933333
# 3      4  0.288432  0.942857
# 2      3  0.342122  0.938095
# 0      1  0.344786  0.895238
# 5      6  1.232539  0.947619
# 4      5  1.263164  0.938095

# %%
depths = [1,2,3,4,5,6]
splits = [2,5,10,20,30]
scores = []
for s in tqdm(splits):
    dtc = DecisionTreeClassifier(criterion='gini',min_samples_split=s,random_state=26)
    dtc.fit(X_train, y_train)
    y_pred_prob = dtc.predict_proba(X_test)
    y_pred = dtc.predict(X_test)
    scores.append([s,log_loss(y_test,y_pred_prob),accuracy_score(y_test,y_pred)])
    
df_scores = pd.DataFrame(scores,columns=["Min Samples in each Node","Log Loss","Accuracy"])
df_scores.sort_values('Log Loss')
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 90.22it/s]
#    Min Samples in each Node  Log Loss  Accuracy
# 4                        30  0.618535  0.933333
# 2                        10  0.731218  0.957143
# 3                        20  0.767550  0.942857
# 0                         2  1.888001  0.947619
# 1                         5  2.073962  0.938095

# %%
depths = [1,2,3,4,5,6]
splits = [2,5,10,20,30]
scores = []
for s in tqdm(splits):
    for d in depths:
        dtc = DecisionTreeClassifier(criterion='gini',min_samples_split=s,random_state=26,max_depth=d)
        dtc.fit(X_train, y_train)
        y_pred_prob = dtc.predict_proba(X_test)
        y_pred = dtc.predict(X_test)
        scores.append([d,s,log_loss(y_test,y_pred_prob),accuracy_score(y_test,y_pred)])
    
df_scores = pd.DataFrame(scores,columns=["Depth","Min Samples in each Node","Log Loss","Accuracy"])
df_scores.sort_values('Log Loss')
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 20.10it/s]
#     Depth  Min Samples in each Node  Log Loss  Accuracy
# 1       2                         2  0.213198  0.933333
# 25      2                        30  0.213198  0.933333
# 7       2                         5  0.213198  0.933333
# 19      2                        20  0.213198  0.933333
# 13      2                        10  0.213198  0.933333
# 3       4                         2  0.288432  0.942857
# 21      4                        20  0.314907  0.938095
# 27      4                        30  0.321503  0.928571
# 14      3                        10  0.342122  0.938095
# 2       3                         2  0.342122  0.938095
# 8       3                         5  0.342122  0.938095
# 20      3                        20  0.342122  0.938095
# 24      1                        30  0.344786  0.895238
# 18      1                        20  0.344786  0.895238
# ...

# %%
depths = [1,2,3,4,5,6]
splits = [1,5,8,10,20]
scores = []
for s in tqdm(splits):
    dtc = DecisionTreeClassifier(criterion='gini',min_samples_leaf=s,random_state=26)
    dtc.fit(X_train, y_train)
    y_pred_prob = dtc.predict_proba(X_test)
    y_pred = dtc.predict(X_test)
    scores.append([s,log_loss(y_test,y_pred_prob),accuracy_score(y_test,y_pred)])
    
df_scores = pd.DataFrame(scores,columns=["Min Leaves in each Node","Log Loss","Accuracy"])
df_scores.sort_values(['Log Loss', 'Accuracy'], ascending = [True, False])
# Out:
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 112.25it/s]
#    Min Leaves in each Node  Log Loss  Accuracy
# 4                       20  0.332581  0.919048
# 1                        5  0.428702  0.942857
# 3                       10  0.461212  0.938095
# 2                        8  0.619772  0.938095
# 0                        1  1.888001  0.947619

# %%
depths_old = np.arange(1,7)
splits_old = np.arange(2,25)
leaves_old = np.arange(1,25)

depths = [1,2,3,5,None]
splits = [2,4,8,10,20,30,50,100]
leaves  = [1,4,8,10,20,30,50,100]

scores = []
for d in tqdm(depths):
    for s in splits:
        for l in leaves:     
            dtc = DecisionTreeClassifier(criterion='gini',min_samples_split=s,random_state=26,max_depth=d,min_samples_leaf=l)
            dtc.fit(X_train, y_train)
            y_pred_prob = dtc.predict_proba(X_test)
            y_pred = dtc.predict(X_test)
            scores.append([d,s,l,log_loss(y_test,y_pred_prob),accuracy_score(y_test,y_pred)])
df_scores = pd.DataFrame(scores,columns=["Depth","Min Samples in each Node to Split",'Min Samples in each Leaf Node',"Log Loss","Accuracy"])
df_scores.sort_values('Log Loss')
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:02<00:00,  2.26it/s]
#      Depth  Min Samples in each Node to Split  Min Samples in each Leaf Node  \
# 69     2.0                                  2                             30
# 85     2.0                                  8                             30
# 125    2.0                                100                             30
# 77     2.0                                  4                             30
# 93     2.0                                 10                             30
# ..     ...                                ...                            ...
# 273    NaN                                  8                              4
# 264    NaN                                  4                              1
# 192    5.0                                  2                              1
# 272    NaN                                  8                              1
# ...

# %%
bm = DecisionTreeClassifier(random_state=26, max_depth = 2, min_samples_split=2, min_samples_leaf=30)
bm.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=30, random_state=26)

# %%
plt.figure(figsize = (25,10))
plot_tree(bm,filled=True, rounded = True,feature_names=list(X.columns),class_names=['Benign','Malignant'],fontsize=12)
plt.show()

# %%
X.columns
# Out:
# Index(['Clump', 'UniCell_Size', 'Uni_CellShape', 'MargAdh', 'SEpith', 'BareN',
#        'BChromatin', 'NoemN', 'Mitoses'],
#       dtype='object')

# %%
bm.feature_importances_
# Out:
# array([0.        , 0.97923669, 0.        , 0.        , 0.        ,
#        0.02076331, 0.        , 0.        , 0.        ])

# %%
df_imp = pd.DataFrame({'feature':X.columns, 'Importance': bm.feature_importances_})
df_imp
# Out:
#          feature  Importance
# 0          Clump    0.000000
# 1   UniCell_Size    0.979237
# 2  Uni_CellShape    0.000000
# 3        MargAdh    0.000000
# 4         SEpith    0.000000
# 5          BareN    0.020763
# 6     BChromatin    0.000000
# 7          NoemN    0.000000
# 8        Mitoses    0.000000

# %%
plt.figure(figsize=(12,10))
hatches=["0","X",".","*","+","*","o","|","O"]
plt.barh(df_imp['feature'], df_imp['Importance'],color=['red','orange','green','yellow','blue','cyan',"purple","grey","white|"],hatch=hatches)
plt.title('Feature Importance Plot')
plt.xlabel('Features')
plt.ylabel('Importance')
# plt.xticks(rotation=45)
plt.grid(True,alpha=0.4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 3
#       1 plt.figure(figsize=(12,10))
#       2 hatches=["0","X",".","*","+","*","o","|","O"]
# ----> 3 plt.barh(df_imp['feature'], df_imp['Importance'],color=['red','orange','green','yellow','blue','cyan',"purple","grey","white|"],hatch=hatches)
#       4 plt.title('Feature Importance Plot')
#       5 plt.xlabel('Features')
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2457, in barh(y, width, height, left, align, data, **kwargs)
#    2453 @_copy_docstring_and_deprecators(Axes.barh)
#    2454 def barh(
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
