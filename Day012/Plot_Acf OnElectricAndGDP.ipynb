# %%
import pandas as pd
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import os
os.chdir("C:/Users/PGCP-AI/ML/MachineLearning/Datasets")

# %%
df_electric = pd.read_csv('Electric_Production.csv')
df_electric
# Out:
#            DATE  IPG2211A2N
# 0    1985-01-01     72.5052
# 1    1985-02-01     70.6720
# 2    1985-03-01     62.4502
# 3    1985-04-01     57.4714
# 4    1985-05-01     55.3151
# ..          ...         ...
# 392  2017-09-01     98.6154
# 393  2017-10-01     93.6137
# 394  2017-11-01     97.3359
# 395  2017-12-01    114.7212
# 396  2018-01-01    129.4048
#
# [397 rows x 2 columns]

# %%
plot_acf(df_electric['IPG2211A2N'],lags=10,alpha=None)
plt.show()

# %%
diff1 = df_electric["IPG2211A2N"].diff().iloc[1:]
plot_acf(diff1,lags=10,alpha=None)
plt.show()

# %%
plot_pacf(diff1,lags=10,alpha=None)
plt.show()

# %%
df = pd.read_csv('gdp-per-capita-ppp-constant-2011.csv')
plot_acf(df['GDP_per_capita'],lags=10,alpha=None)
plt.show()
