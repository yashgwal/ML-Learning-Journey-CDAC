# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
os.chdir('/home/pgcp-ai/MachineLearning/Datasets')

# %%
pizza = pd.read_csv("pizza.csv")
X = pizza[['Promote']]
y = pizza['Sales']
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.coef_, lr.intercept_
# Out:
# (array([23.50640302]), 5.4858653632529695)

# %% [markdown]
# ### Linear Regression for second Dataset boston

# %%
boston = pd.read_csv("Boston.csv")
X = boston.drop('medv', axis = 1)
y = boston['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 26)
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

print("MAE = ", mean_absolute_error(y_test, y_pred))
print("RMSE = ", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 = ", r2_score(y_test, y_pred))
print(f"R2 Score in percentage =  {r2_score(y_test,y_pred):.2%}")
# Out:
# MAE =  3.152771430384485
# RMSE =  4.504438687188599
# R2 =  0.7467569320916609
# R2 Score in percentage =  74.68%

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in /home/pgcp-ai/.local/lib/python3.8/site-packages (1.3.2)
# ...
