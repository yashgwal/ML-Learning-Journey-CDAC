# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import os
os.chdir('/home/pgcp-ai/MachineLearning/Datasets')

# %%
boston = pd.read_csv("Boston.csv")
X = boston.drop('medv', axis = 1)
y = boston['medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=26)

# %%
alpha_values = np.linspace(0.001, 5,20)
l1_ratios = np.linspace(0,1,20)
dict_alpha = dict()
scores = []
for i,j in zip(alpha_values,l1_ratios):
    el = ElasticNet(alpha = i,l1_ratio=j)
    el.fit(X_train, y_train)
    y_pred_ElasticNet = el.predict(X_test)
    dict_alpha[i] = r2_score(y_test, y_pred_ElasticNet)
    scores.append([i,j, r2_score(y_test, y_pred_ElasticNet)])
# ElasticNet_df = pd.DataFrame(dict_alpha.items(), columns = ['Alpha', 'Score'])
# ElasticNet_df.sort_values('Score', ascending = False)

df1 = pd.DataFrame(scores, columns = ['Alpha', 'L1 Ratio', 'Score'])
df1.sort_values('Score', ascending = False)
# Out:
# /home/pgcp-ai/.local/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.121e+03, tolerance: 3.044e+00 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
#        Alpha  L1 Ratio     Score
# 0   0.001000  0.000000  0.746268
# 1   0.264105  0.052632  0.742288
# 2   0.527211  0.105263  0.731731
# 3   0.790316  0.157895  0.722505
# 4   1.053421  0.210526  0.714103
# 5   1.316526  0.263158  0.705872
# 6   1.579632  0.315789  0.697110
# 7   1.842737  0.368421  0.687430
# 8   2.105842  0.421053  0.676430
# 9   2.368947  0.473684  0.663634
# 10  2.632053  0.526316  0.648450
# ...
