# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve,roc_auc_score,RocCurveDisplay, log_loss
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')
os.chdir("/home/pgcp-ai/MachineLearning/Cases/Image_Segmentation/")

# %%
image = pd.read_csv("Image_Segmentation.csv")
image
# Out:
#          Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0    BRICKFACE                  188                  133                   9
# 1    BRICKFACE                  105                  139                   9
# 2    BRICKFACE                   34                  137                   9
# 3    BRICKFACE                   39                  111                   9
# 4    BRICKFACE                   16                  128                   9
# ..         ...                  ...                  ...                 ...
# 204      GRASS                   36                  243                   9
# 205      GRASS                  186                  218                   9
# 206      GRASS                  197                  236                   9
# 207      GRASS                  208                  240                   9
# 208      GRASS                  223                  185                   9
#
# ...

# %%
image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 209 non-null    object
#  1   region.centroid.col   209 non-null    int64
#  2   region.centroid.row   209 non-null    int64
#  3   region.pixel.count    209 non-null    int64
#  4   short.line.density.5  209 non-null    float64
#  5   short.line.density.2  209 non-null    float64
#  6   vedge.mean            209 non-null    float64
#  7   vegde.sd              209 non-null    float64
#  8   hedge.mean            209 non-null    float64
#  9   hedge.sd              209 non-null    float64
#  10  intensity.mean        209 non-null    float64
#  11  rawred.mean           209 non-null    float64
#  12  rawblue.mean          209 non-null    float64
#  13  rawgreen.mean         209 non-null    float64
# ...

# %%
image.isna().sum()
# Out:
# Class                   0
# region.centroid.col     0
# region.centroid.row     0
# region.pixel.count      0
# short.line.density.5    0
# short.line.density.2    0
# vedge.mean              0
# vegde.sd                0
# hedge.mean              0
# hedge.sd                0
# intensity.mean          0
# rawred.mean             0
# rawblue.mean            0
# rawgreen.mean           0
# exred.mean              0
# exblue.mean             0
# exgreen.mean            0
# value.mean              0
# saturation.mean         0
# hue-mean                0
# dtype: int64

# %%
le = LabelEncoder()
image['Class'] = le.fit_transform(image['Class'])
X, y = image.drop('Class', axis = 1), image['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 26, stratify = image['Class'])

# %%
solvers=['lbfgs','newton-cg','newton-cholesky','sag','saga']
C = np.linspace(0.001, 10, 30)

scores = []
for i in solvers:
    for j in C:
        lr = LogisticRegression(solver=i, C = j)
        lr.fit(X_train, y_train)
        y_pred = lr.predict_proba(X_test)
        scores.append([i, j, log_loss(y_test, y_pred)])

# %%
df_scores = pd.DataFrame(scores, columns = ['Solver', 'C', 'Log Loss Score'])

# %%
df_scores.sort_values('Log Loss Score', ascending=True)
# Out:
#               Solver         C  Log Loss Score
# 30         newton-cg  0.001000        0.477194
# 60   newton-cholesky  0.001000        0.643561
# 118              sag  9.655207        0.796496
# 107              sag  5.862483        0.797846
# 112              sag  7.586448        0.798228
# ..               ...       ...             ...
# 13             lbfgs  4.483310        1.847779
# 26             lbfgs  8.965621        1.868138
# 17             lbfgs  5.862483        1.885943
# 18             lbfgs  6.207276        1.946807
# 27             lbfgs  9.310414        1.977704
#
# [150 rows x 3 columns]

# %%
tst_img = pd.read_csv("tst_img.csv")
bm = LogisticRegression(solver = "newton-cg", C = 0.001)
bm.fit(X, y)
# Out:
# LogisticRegression(C=0.001, solver='newton-cg')

# %%
tst_img['predicted_class'] = le.inverse_transform(bm.predict(tst_img))

# %%
tst_img
# Out:
#    region.centroid.col  region.centroid.row  region.pixel.count  \
# 0                   22                   90                  10
# 1                  210                  200                   9
# 2                  240                  184                   9
# 3                  130                  191                   9
#
#    short.line.density.5  short.line.density.2  vedge.mean  vegde.sd  \
# 0                     0                     0    0.666668  0.044444
# 1                     0                     0    1.300000  0.998145
# 2                     0                     0    0.500000  0.077778
# 3                     0                     0    1.000000  0.400000
#
#    hedge.mean  hedge.sd  intensity.mean  rawred.mean  rawblue.mean  \
# 0    0.880000  0.562963      112.000000   105.888885    128.555560
# 1    1.611111  1.123816       49.481480    45.000000     60.666668
# 2    0.777778  0.785185       11.851851     9.777778      9.888889
# ...
