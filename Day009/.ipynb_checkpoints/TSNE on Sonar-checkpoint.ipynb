# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from pca import pca
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
os.chdir('/home/pgcp-ai/MachineLearning/Cases/Wisconsin/')

# %%
cancer = pd.read_csv("BreastCancer.csv", index_col = 0)
cancer
# Out:
#           Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# Code
# 61634         5             4              3        1       2      2
# 63375         9             1              2        6       4     10
# 76389        10             4              7        2       2      8
# 95719         6            10             10       10       8     10
# 128059        1             1              1        1       2      5
# ...         ...           ...            ...      ...     ...    ...
# 1369821      10            10             10       10       5     10
# 1371026       5            10             10       10       4     10
# 1371920       5             1              1        1       2      1
# 8233704       4             1              1        1       1      1
# 13454352      1             1              3        1       2      1
#
#           BChromatin  NoemN  Mitoses      Class
# Code
# 61634              2      3        1     Benign
# 63375              7      7        2  Malignant
# 76389              6      1        1  Malignant
# 95719              7     10        7  Malignant
# 128059             5      1        1     Benign
# ...              ...    ...      ...        ...
# 1369821           10     10        7  Malignant
# 1371026            5      6        3  Malignant
# 1371920            3      2        1     Benign
# 8233704            2      1        1     Benign
# 13454352           2      1        1     Benign
#
# [699 rows x 10 columns]

# %%
X, y = cancer.drop('Class', axis = 1), cancer['Class']

# %%
tsne = TSNE(random_state = 26).set_output(transform = 'pandas')
X_tsne = tsne.fit_transform(X)
tsne_data = pd.concat([X_tsne, y], axis = 1)
tsne_data.columns
# Out:
# Index(['tsne0', 'tsne1', 'Class'], dtype='object')

# %%
sns.scatterplot(data = tsne_data, x = 'tsne0', y = 'tsne1', hue = 'Class')
# Out:
# <Axes: xlabel='tsne0', ylabel='tsne1'>

# %%
np.cumsum(prcomp.explained_variance_ratio_)*100
# Out:
# array([ 68.92148641,  76.17490546,  82.27277194,  86.70847108,
#         90.60818755,  94.06577109,  96.59348125,  98.86016534,
#        100.        ])

# %%
pca_data = X_pca.copy()
pca_data['Class'] = y
sns.scatterplot(data = pca_data, x = 'pca0', y = 'pca1', hue = 'Class')
plt.show()

# %%
X_pca.values
# Out:
# array([[-1.57841013,  1.25095202, -1.69774187, ...,  1.30962487,
#         -0.51207481,  1.02275621],
#        [ 6.68545934, -4.12183441, -0.7124457 , ..., -2.50879127,
#          1.20256752, -0.74975801],
#        [ 4.89908205, -4.10229349, -5.16877536, ..., -0.43818012,
#         -1.78611146, -1.68040045],
#        ...,
#        [-4.08126534,  0.57542221, -1.59605535, ..., -0.89485118,
#          0.13071976,  0.01115609],
#        [-5.27938656, -0.04679289, -1.04786339, ...,  0.05818393,
#         -0.59439747,  0.17930615],
#        [-5.13850741,  0.60975875,  1.41164787, ...,  0.5318913 ,
#         -0.59112945, -1.28662124]])

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=26,stratify=y)

# %%
prcomp = PCA().set_output(transform='pandas')
X_trn_pca = prcomp.fit_transform(X_train)
X_trn_pca = X_trn_pca.iloc[:,:2]
X_tst_pca = prcomp.transform(X_test)
X_tst_pca = X_tst_pca.iloc[:,:2]
svm = SVC(kernel='linear')
svm.fit(X_trn_pca,y_train)
y_pred = svm.predict(X_tst_pca)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.98      0.95      0.97       138
#    Malignant       0.91      0.97      0.94        72
#
#     accuracy                           0.96       210
#    macro avg       0.95      0.96      0.95       210
# weighted avg       0.96      0.96      0.96       210

# %%
eigenvalues, eigenvectors = np.linalg.eig(X_pca.cov())
eigenvectors
# Out:
# array([[ 1.00000000e+00, -3.56709739e-17, -3.13290819e-17,
#          8.96744785e-18, -2.46865497e-17, -4.09534745e-17,
#          3.53712010e-17, -1.19416122e-17,  1.04627436e-17],
#        [ 0.00000000e+00, -1.00000000e+00, -3.95528274e-15,
#          9.53477925e-17, -7.37511075e-16,  4.17704395e-17,
#         -9.07212784e-17,  3.32175810e-16, -3.09410614e-17],
#        [ 0.00000000e+00, -4.44195319e-15,  1.00000000e+00,
#         -4.52417847e-17, -5.38228189e-16, -7.29978780e-16,
#          1.65548447e-16, -3.22221838e-17, -1.70410853e-16],
#        [ 0.00000000e+00, -1.02270527e-15,  7.01738798e-16,
#         -3.61123694e-16,  1.00000000e+00,  2.74893383e-15,
#          1.36908941e-15,  4.47918453e-16, -2.16442830e-16],
#        [ 0.00000000e+00, -8.66060693e-16,  7.31160011e-16,
#         -5.58398972e-16, -4.33997799e-15,  1.00000000e+00,
#         -1.88393423e-15, -3.60491454e-17,  7.99522713e-16],
#        [ 0.00000000e+00,  3.84463686e-16, -1.80460139e-16,
#          4.03069432e-17, -2.03127230e-15,  1.37078133e-15,
#          1.00000000e+00,  7.75491093e-16,  1.16296938e-15],
#        [ 0.00000000e+00, -5.30728845e-17, -4.60761583e-17,
#         -6.25576182e-17, -2.80319996e-16,  3.74159669e-16,
#          1.89704579e-16,  1.80905055e-15, -1.00000000e+00],
#        [ 0.00000000e+00,  1.72977965e-16,  6.18631033e-17,
#          7.19150540e-16,  2.04918997e-16, -3.18112457e-16,
#         -4.73392803e-16,  1.00000000e+00,  1.05135987e-15],
#        [ 0.00000000e+00, -2.41264677e-16,  2.22241228e-16,
#         -1.00000000e+00, -4.58414716e-16, -5.92621745e-16,
#          2.93632247e-16,  1.01404297e-15, -2.05524849e-17]])
